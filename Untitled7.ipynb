# %% [markdown]
# <a href="https://colab.research.google.com/github/kellySanchezA/cursopy2023/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=4c4a5398dad614aa7f1cd5753b08b1a35ccb40f132432236044f4933a77eb13f
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle.Turtle import*

# %%
import ColabTurtle

# %%
lado= int (input("Dame el número de lados "))
initializeTurtle()
pencolor("red")
for i in range(lado):#[1,2,3,4]:
  pencolor("red")
  forward(150)
  left(360/ lado)
  for i in range(lado):#[1,2,3,4]:
    pencolor("blue")
    forward(100)
    left(360/ lado)
    for i in range(lado):#[1,2,3,4]:
      pencolor("purple")
      forward(50)
      left(360/ lado)
# Out:
# Dame el número de lados 3
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
colors_list=["red","purple", "blue", "green", "orange", "yellow"]

# %%
lado= int (input("Dame el número de lados "))
initializeTurtle()
for i in range(lado):#[1,2,3,4]:
  pencolor (colors_list[i % 6])
  width(int (i/100)+1)
  forward(150)
  left(360/ lado)
  for i in range(lado):#[1,2,3,4]:
    pencolor (colors_list[i % 6])
    width(int (i/100)+1)
    forward(100)
    left(360/ lado)
    for i in range(lado):#[1,2,3,4]:
      pencolor (colors_list[i% 6])
      width(int (i/100)+1)
      forward(50)
      left(360/ lado)
# Out:
# Dame el número de lados 6
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
